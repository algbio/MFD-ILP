# %%
import sys
print(sys.version)
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx
import itertools
import gfapy
from smithnormalform import matrix, snfproblem, z
# Out:
# 3.8.8 (default, Apr 13 2021, 12:59:45)
# [Clang 10.0.0 ]

# %%
def flowMultipleDecomposition(data,K):
    
   
    # calculate the minimal flow decomposition based on such graph
    V = data['vertices']
    E = data['edges']
    f = data['flows']
    W = 5
    S = {str(min(map(int,V)))}
    D = {str(max(map(int,V)))}
    
    print()

    
    # import library
    from docplex.mp.model import Model

    # model name
    Flow = Model(name = 'Flow Decomposition')

    # define variables
    x = {(i,j,k): Flow.binary_var(name="x_{0}_{1}_{2}".format(i,j,k)) for (i,j) in E for k in range(0,K)}
    w = {(k): Flow.integer_var(name="w_{0}_".format(k)) for k in range(0,K)}
    z = {(i,j,k): Flow.integer_var(name="z_{0}_{1}_{2}".format(i,j,k)) for (i,j) in E for k in range(0,K)}

    # flow conservation
    for k in range(0,K):
        for i in V:
            if i in S:
                Flow.add_constraint(sum(x[i,j,k] for j in V if i!=j and(i,j) in E) - sum(x[j,i,k] for j in V if i!=j and (j,i) in E) == 1)  
            if i in D:
                Flow.add_constraint(sum(x[i,j,k] for j in V if i!=j and (i,j) in E) - sum(x[j,i,k] for j in V if i!=j and (j,i) in E) == -1)
            if i not in S and i not in D:
                Flow.add_constraint(sum(x[i,j,k] for j in V if i!=j and (i,j) in E) - sum(x[j,i,k] for j in V if i!=j and (j,i) in E) == 0)
    
    # flow balance
    for (i,j) in E:
        Flow.add_constraint(f[i,j] == sum(z[i,j,k] for k in range(0,K)))
        
    
    # linearization
    for (i,j) in E:
        for k in range(0,K):
            Flow.add_constraint(z[i,j,k] <= W*x[i,j,k])
            Flow.add_constraint(w[k] - (1 - x[i,j,k])*W <= z[i,j,k])
            Flow.add_constraint(z[i,j,k] <= w[k])
            #Flow.add_constraint(z[i,j,k] >= 0)
    
    # objective function
    #Flow.minimize(sum(w[k] for k in range(0,K)))
    Flow.minimize(1)
    
    Flow.parameters.threads = 8
    Flow.parameters.mip.display = 0
    Flow.parameters.timelimit = 60
    #Flow.parameters.conflict.display = 1
    #Flow.parameters.emphasis.mip = 0
    #Flow.parameters.mip.pool.intensity = 4
    
    Flow.print_information()
    sol = Flow.solve(log_output=False)
    print('status',Flow.solve_details.status)

    if Flow.solve_details.status == 'integer infeasible' or Flow.solve_details.status == 'time limit exceeded, no integer solution':
        data['messsage'] = "infeasible"
        return data

    elif Flow.solve_details.status == 'time limit exceeded':
        print('time limit')

    #print('FD obj value',Flow.objective_value)    
    #print('FD best bound (LB)',Flow.solve_details.best_bound)    
    print('FD time',Flow.solve_details.time)

    # calculate averages
    x_sol = {(i,j,k):Flow.solution.get_value(x[(i,j,k)]) for (i,j) in E for k in range(0,K)}
    w_sol = {(k):Flow.solution.get_value(w[(k)]) for (k) in range(0,K)}
    paths =[list() for i in range(0,K)]
    for k in range(0,K):
        for (i,j) in E:
            if x_sol[i,j,k] == 1:
                paths[k].append((i,j))
               
    data['weights'] = w_sol
    data['solution'] = paths
    data['message'] = 'solved'
    data['runtime'] = Flow.solve_details.time
    
    return data;

# %%
def FD_Algorithm(data):
    
    listOfEdges = data['edges']
    solutionMap = data['graph']
    solutionSet = 0
    Kmin = data['minK']
    solutionWeights = 0

    for i in range(1,len(listOfEdges)+1):
    #for i in range(16,17):
        print("")
        print("Iteration",i)
        print()
        #data = flowMultipleDecomposition(data,)
        data = flowMultipleDecomposition(data,i)
        if data['message'] == "solved":
            solutionSet = data['solution']
            solutionWeights = data['weights']
            break;
        
    # display solutions
    print()
    colors = ['red','green','yellow','cyan','purple','violet']
    edges = list(solutionMap.edges())
    edges_colors = [0]*len(edges)
    edges_weights = [0]*len(edges)
    
    for i in range(0,len(solutionSet)):
        for k in range(0,len(edges)):
            edges_colors[k] = "beige"
        plt.figure()
        my_pos = nx.spring_layout(solutionMap, seed = 100)
        
        for j in solutionSet[i]:
            if j in edges:
                edges_colors[edges.index(j)] = "red"
                edges_weights[edges.index(j)] = 2
        
            
        print("W:",solutionWeights[i])
        nx.draw(solutionMap, pos = my_pos,edge_color=edges_colors,with_labels=True, node_color='lightblue', node_size=400, linewidths= edges_weights, font_size=15)
        plt.show()
    
    # convert solution to paths
    #for k in range(len(solutionSet)):
    #    print(solutionSet[k])
    
    return data

# %%
def inputs(graphfile,truthfile):

    trip_data = open(graphfile,'r').read().split('\n')
    i = 0
    listOfGraphs = {}
    k = 0
    
    while(True):
        if "#" in trip_data[i]:
            #new graph
            i = i+1
            N = int(trip_data[i])
            edges = list()
            while(True):
                i = i+1;
                if "#" in trip_data[i]:
                    break;
                if "" == trip_data[i]:
                    break;
                line = trip_data[i].split(" ")
                edges.append((line[0],line[1],line[2]))
                if i >= len(trip_data)-1:
                    break;
            G = {'Nodes':N,'list of edges': edges}
            listOfGraphs[k] = G
            k +=1 
        if i >= len(trip_data)-1:
                    break; 

    # read ground truth
    #trip_truth = open(''.join([truthfile,'.truth']),'r').read().split('\n')
    #i = 0 
    #listOfSolutions = {}
    #k = 0
    #while(True):
        
    #    if '#' in trip_truth[i]:
    #        #new solution
    #        i = i +1
    #        weights_list = list()
    #        paths = list()
    #        while(True):
    #            if "#" in trip_truth[i]:
    #                break;
    #            line = trip_truth[i].split(" ")
    #            weights_list.append(line[0])
    #            paths.append(list(line[1:len(line)-1]))
    #            i = i + 1
                
    #            if i >= len(trip_truth)-1:
    #                break;
                
        
    #    T = {'weights': weights_list,'flow-paths': paths}
    #    listOfSolutions[k] = T
    #    k +=1
    #    if i >= len(trip_truth)-1:
    #        break;
        
        
    
    return listOfGraphs#,listOfSolutions

# %%
def SolveInstances(Graphs):
    
    runtime = [0 for i in range(1,len(Graphs))]
    klength = [0 for i in range(1,len(Graphs))]
    
    for i in range(0,len(Graphs)): 
    #    print(i)
    #for i in range():
    #for i in range(12753,12754):   
        # set in up data
        
        f = {}
        Edges = set()
        V = set()
        listOfEdges = Graphs[i]['list of edges']
        for k in range(0,len(listOfEdges)):
            (a,b,c) = (listOfEdges[k])
            Edges.add((a,b))
            V.add(a)
            V.add(b)
            f[a,b] = int(float(c))
            
        
        # creation of graphs
        G = nx.DiGraph()
        G.add_edges_from(Edges,weights = f)
        G.add_nodes_from(V)
        
        
        # calculating topological order
        G_top = nx.topological_sort(G)
        G_top_list = list(nx.topological_sort(G))
        topological_cuts = sorted(G.degree, key=lambda x: x[1], reverse=True)[0][1]
        
        # definition of data
        
        data = {'edges' : Edges,
                'flows' : f,
                'vertices' : V,
                'graph' : G,
                'Kmax' : len(Edges),
                'weights' : {},
                'message': {},
                'minK': topological_cuts,
                'runtime': 0,
        }
        
        data = FD_Algorithm(data)
        runtime[i-1] = data['runtime']
        klength[i-1] = len(data['weights'])
    
    
    data = {'runtime': runtime, 'paths_size': klength}   
    return data

# %%
def outputFiles(data,outfileName):
    
    
    runtime = data['runtime']
    klength = data['paths_size']
        
    fp = open(outfileName,'w+')
    
    for i in range(0,len(runtime)):
        print(klength[i],runtime[i],file=fp)
    
    return 0

# %%
def getSafety(ground_truth):
    
    for i in range(0,len(ground_truth)):
        print(ground_truth[i]['weights'])
    
    return 0

# %%
path = "./data/rnaseq/test/"
text_files = [f for f in os.listdir(path) if f.endswith('.graph')]

for i in range(0,1):    
    filename = text_files[i]
    #print(filename)
    outfileName = "".join([filename.split(".")[0],"_test_results.txt"])
    data = inputs(''.join([path,filename]),''.join([path,filename.split(".")[0]]))
    #getSafety(ground_truth)
    data = SolveInstances(data)
    outputFiles(data,outfileName)
    
print("Done")
# Out:
# Iteration 1
#
#
# Model: Flow Decomposition
#  - number of variables: 89
#    - binary=44, integer=45, continuous=0
#  - number of constraints: 207
#    - linear=207
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 2
#
#
# Model: Flow Decomposition
#  - number of variables: 178
#    - binary=88, integer=90, continuous=0
#  - number of constraints: 370
#    - linear=370
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 3
#
#
# Model: Flow Decomposition
#  - number of variables: 267
#    - binary=132, integer=135, continuous=0
#  - number of constraints: 533
#    - linear=533
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 4
#
#
# Model: Flow Decomposition
#  - number of variables: 356
#    - binary=176, integer=180, continuous=0
#  - number of constraints: 696
#    - linear=696
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 5
#
#
# Model: Flow Decomposition
#  - number of variables: 445
#    - binary=220, integer=225, continuous=0
#  - number of constraints: 859
#    - linear=859
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 6
#
#
# Model: Flow Decomposition
#  - number of variables: 534
#    - binary=264, integer=270, continuous=0
#  - number of constraints: 1022
#    - linear=1022
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 7
#
#
# Model: Flow Decomposition
#  - number of variables: 623
#    - binary=308, integer=315, continuous=0
#  - number of constraints: 1185
#    - linear=1185
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 8
#
#
# Model: Flow Decomposition
#  - number of variables: 712
#    - binary=352, integer=360, continuous=0
#  - number of constraints: 1348
#    - linear=1348
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 9
#
#
# Model: Flow Decomposition
#  - number of variables: 801
#    - binary=396, integer=405, continuous=0
#  - number of constraints: 1511
#    - linear=1511
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 10
#
#
# Model: Flow Decomposition
#  - number of variables: 890
#    - binary=440, integer=450, continuous=0
#  - number of constraints: 1674
#    - linear=1674
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 11
#
#
# Model: Flow Decomposition
#  - number of variables: 979
#    - binary=484, integer=495, continuous=0
#  - number of constraints: 1837
#    - linear=1837
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 12
#
#
# Model: Flow Decomposition
#  - number of variables: 1068
#    - binary=528, integer=540, continuous=0
#  - number of constraints: 2000
#    - linear=2000
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 13
#
#
# Model: Flow Decomposition
#  - number of variables: 1157
#    - binary=572, integer=585, continuous=0
#  - number of constraints: 2163
#    - linear=2163
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 14
#
#
# Model: Flow Decomposition
#  - number of variables: 1246
#    - binary=616, integer=630, continuous=0
#  - number of constraints: 2326
#    - linear=2326
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 15
#
#
# Model: Flow Decomposition
#  - number of variables: 1335
#    - binary=660, integer=675, continuous=0
#  - number of constraints: 2489
#    - linear=2489
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 16
#
#
# Model: Flow Decomposition
#  - number of variables: 1424
#    - binary=704, integer=720, continuous=0
#  - number of constraints: 2652
#    - linear=2652
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 17
#
#
# Model: Flow Decomposition
#  - number of variables: 1513
#    - binary=748, integer=765, continuous=0
#  - number of constraints: 2815
#    - linear=2815
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 18
#
#
# Model: Flow Decomposition
#  - number of variables: 1602
#    - binary=792, integer=810, continuous=0
#  - number of constraints: 2978
#    - linear=2978
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 19
#
#
# Model: Flow Decomposition
#  - number of variables: 1691
#    - binary=836, integer=855, continuous=0
#  - number of constraints: 3141
#    - linear=3141
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 20
#
#
# Model: Flow Decomposition
#  - number of variables: 1780
#    - binary=880, integer=900, continuous=0
#  - number of constraints: 3304
#    - linear=3304
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 21
#
#
# Model: Flow Decomposition
#  - number of variables: 1869
#    - binary=924, integer=945, continuous=0
#  - number of constraints: 3467
#    - linear=3467
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 22
#
#
# Model: Flow Decomposition
#  - number of variables: 1958
#    - binary=968, integer=990, continuous=0
#  - number of constraints: 3630
#    - linear=3630
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 23
#
#
# Model: Flow Decomposition
#  - number of variables: 2047
#    - binary=1012, integer=1035, continuous=0
#  - number of constraints: 3793
#    - linear=3793
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 24
#
#
# Model: Flow Decomposition
#  - number of variables: 2136
#    - binary=1056, integer=1080, continuous=0
#  - number of constraints: 3956
#    - linear=3956
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 25
#
#
# Model: Flow Decomposition
#  - number of variables: 2225
#    - binary=1100, integer=1125, continuous=0
#  - number of constraints: 4119
#    - linear=4119
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 26
#
#
# Model: Flow Decomposition
#  - number of variables: 2314
#    - binary=1144, integer=1170, continuous=0
#  - number of constraints: 4282
#    - linear=4282
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 27
#
#
# Model: Flow Decomposition
#  - number of variables: 2403
#    - binary=1188, integer=1215, continuous=0
#  - number of constraints: 4445
#    - linear=4445
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 28
#
#
# Model: Flow Decomposition
#  - number of variables: 2492
#    - binary=1232, integer=1260, continuous=0
#  - number of constraints: 4608
#    - linear=4608
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 29
#
#
# Model: Flow Decomposition
#  - number of variables: 2581
#    - binary=1276, integer=1305, continuous=0
#  - number of constraints: 4771
#    - linear=4771
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 30
#
#
# Model: Flow Decomposition
#  - number of variables: 2670
#    - binary=1320, integer=1350, continuous=0
#  - number of constraints: 4934
#    - linear=4934
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 31
#
#
# Model: Flow Decomposition
#  - number of variables: 2759
#    - binary=1364, integer=1395, continuous=0
#  - number of constraints: 5097
#    - linear=5097
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 32
#
#
# Model: Flow Decomposition
#  - number of variables: 2848
#    - binary=1408, integer=1440, continuous=0
#  - number of constraints: 5260
#    - linear=5260
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 33
#
#
# Model: Flow Decomposition
#  - number of variables: 2937
#    - binary=1452, integer=1485, continuous=0
#  - number of constraints: 5423
#    - linear=5423
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 34
#
#
# Model: Flow Decomposition
#  - number of variables: 3026
#    - binary=1496, integer=1530, continuous=0
#  - number of constraints: 5586
#    - linear=5586
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 35
#
#
# Model: Flow Decomposition
#  - number of variables: 3115
#    - binary=1540, integer=1575, continuous=0
#  - number of constraints: 5749
#    - linear=5749
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 36
#
#
# Model: Flow Decomposition
#  - number of variables: 3204
#    - binary=1584, integer=1620, continuous=0
#  - number of constraints: 5912
#    - linear=5912
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 37
#
#
# Model: Flow Decomposition
#  - number of variables: 3293
#    - binary=1628, integer=1665, continuous=0
#  - number of constraints: 6075
#    - linear=6075
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 38
#
#
# Model: Flow Decomposition
#  - number of variables: 3382
#    - binary=1672, integer=1710, continuous=0
#  - number of constraints: 6238
#    - linear=6238
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 39
#
#
# Model: Flow Decomposition
#  - number of variables: 3471
#    - binary=1716, integer=1755, continuous=0
#  - number of constraints: 6401
#    - linear=6401
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 40
#
#
# Model: Flow Decomposition
#  - number of variables: 3560
#    - binary=1760, integer=1800, continuous=0
#  - number of constraints: 6564
#    - linear=6564
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 41
#
#
# Model: Flow Decomposition
#  - number of variables: 3649
#    - binary=1804, integer=1845, continuous=0
#  - number of constraints: 6727
#    - linear=6727
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 42
#
#
# Model: Flow Decomposition
#  - number of variables: 3738
#    - binary=1848, integer=1890, continuous=0
#  - number of constraints: 6890
#    - linear=6890
#  - parameters:
#      parameters.threads = 8
#      parameters.timelimit = 60.00000000000000
#      parameters.mip.display = 0
#  - objective: none
#  - problem type is: MILP
# status integer infeasible
#
# Iteration 43
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-64c9d10a9271> in <module>
#       8     data = inputs(''.join([path,filename]),''.join([path,filename.split(".")[0]]))
#       9     #getSafety(ground_truth)
# ---> 10     data = SolveInstances(data)
#      11     outputFiles(data,outfileName)
#      12
#
# <ipython-input-5-0be2ebde3c44> in SolveInstances(Graphs)
#      46         }
#      47
# ---> 48         data = FD_Algorithm(data)
#      49         runtime[i-1] = data['runtime']
#      50         klength[i-1] = len(data['weights'])
#
# <ipython-input-3-bcf8f14ad279> in FD_Algorithm(data)
#      13         print()
#      14         #data = flowMultipleDecomposition(data,)
# ---> 15         data = flowMultipleDecomposition(data,i)
#      16         if data['message'] == "solved":
#      17             solutionSet = data['solution']
#
# <ipython-input-2-ab9d85cc9460> in flowMultipleDecomposition(data, K)
#      43         for k in range(0,K):
#      44             Flow.add_constraint(z[i,j,k] <= W*x[i,j,k])
# ---> 45             Flow.add_constraint(w[k] - (1 - x[i,j,k])*W <= z[i,j,k])
#      46             Flow.add_constraint(z[i,j,k] <= w[k])
#      47             #Flow.add_constraint(z[i,j,k] >= 0)
#
# /opt/anaconda3/lib/python3.8/site-packages/docplex/mp/linear.py in __mul__(self, e)
#    1082
#    1083     def __mul__(self, e):
# -> 1084         return self.times(e)
#    1085
#    1086     def __rmul__(self, e):
#
# /opt/anaconda3/lib/python3.8/site-packages/docplex/mp/linear.py in times(self, e)
#    1028             A new instance of expression.
#    1029         """
# -> 1030         cloned = self.clone_if_necessary()
#    1031         return cloned.multiply(e)
#    1032
#
# /opt/anaconda3/lib/python3.8/site-packages/docplex/mp/linear.py in clone_if_necessary(self)
#     463             return self
#     464         else:
# --> 465             return self.clone()
#     466
#     467     def set_name(self, name):
#
# /opt/anaconda3/lib/python3.8/site-packages/docplex/mp/linear.py in clone(self)
#     484         """
#     485         cloned_terms = self._new_terms_dict(self._model, self.__terms)  # faster than copy() on OrderedDict()
# --> 486         cloned = LinearExpr(model=self._model, e=cloned_terms, constant=self._constant, safe=True)
#     487         return cloned
#     488
#
# /opt/anaconda3/lib/python3.8/site-packages/docplex/mp/linear.py in __init__(self, model, e, constant, name, safe, transient)
#     398         return id(self)
#     399
# --> 400     def __init__(self, model, e=None, constant=0, name=None, safe=False, transient=False):
#     401         ModelingObjectBase.__init__(self, model, name)
#     402         if not safe and constant:
#
# KeyboardInterrupt:

# %%
path = "./data/rnaseq/salmon/"
text_files = [f for f in os.listdir(path) if f.endswith('.graph')]

for i in range(0,10):    
    filename = text_files[i]
    print(filename)
    outfileName = "".join([filename.split(".")[0],"_zebrafish_results.txt"])
    data,ground_truth = inputs(''.join([path,filename]),''.join([path,filename.split(".")[0]]))
    data = SolveInstances(data)
    outputFiles(data,outfileName)
    
print("Done")

# %%
path = "./data/rnaseq/zebrafish/"
text_files = [f for f in os.listdir(path) if f.endswith('.graph')]

for i in range(0,-10):    
    filename = text_files[i]
    print(filename)
    outfileName = "".join([filename.split(".")[0],"_zebrafish_results.txt"])
    data,ground_truth = inputs(''.join([path,filename]),''.join([path,filename.split(".")[0]]))
    data = SolveInstances(data)
    outputFiles(data,outfileName)
    
print("Done")

# %%
path = "./data/rnaseq/human/"
text_files = [f for f in os.listdir(path) if f.endswith('.graph')]

#for i in text_files:
for i in range(7,-10):
    filename = text_files[i]
    print(filename)
    outfileName = "".join([filename.split(".")[0],"_human_results.txt"])
    data,ground_truth = inputs(''.join([path,filename]),''.join([path,filename.split(".")[0]]))
    data = SolveInstances(data)
    outputFiles(data,outfileName)
    
print("Done")
